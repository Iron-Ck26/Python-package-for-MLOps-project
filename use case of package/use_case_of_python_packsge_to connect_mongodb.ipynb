# %% [markdown]
# ### install Package from pypi

# %%
# !pip install Python-mongoDB-Connect1==0.0.4

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ---------
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anyio                             4.2.0
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.4.1
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             23.1.0
# Automat                           20.2.0
# autopep8                          2.0.4
# Babel                             2.11.0
# bcrypt                            3.2.0
# ...

# %% [markdown]
# ### Mantion or call the file wher package is create
#  file is in src/mongodb_connect call file from folder (mongodb_connect) and import the file (mongo_crud)

# %%
from mongodb_connect import mongo_crud
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from mongodb_connect import mongo_crud
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\mongodb_connect\mongo_crud.py:6
#       4 from pymongo.mongo_client import MongoClient
#       5 import json
# ----> 6 from ensure import ensure_annotations
#       8 class mongo_operation:
#       9     __collection = None  # Here I have created a private/protected variable
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\ensure\__init__.py:4
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 4 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_raises_regex, ensure_annotations
#
# ...

# %%
# !pip install pymongo

# %%
 #call the mongodb connection 
client_url =  "mongodb+srv://Iron_Ck:55252555_Ck@mlops-mongodb-cluster1.etxtatl.mongodb.net/?retryWrites=true&w=majority&appName=MLOps-MongoDB-Cluster1"
database = "My_New_Database"
collection_name = "New_collection"

# %%
mongo = mongo_crud.mongo_operation(client_url, database, collection_name)

# %%
mongo.insert_record({"name":"chakrapani waghmode","designation":"data scientist","salary":"30k"}, collection_name)
